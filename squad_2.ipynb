# %% [markdown]
# Replicating: https://github.com/superlinked/chunking-research

# %%
import datasets
from tqdm import tqdm
import pandas as pd

dataset = datasets.load_dataset("rajpurkar/squad")

# %%
df = pd.concat(
    [
        pd.DataFrame(dataset["train"]),
        pd.DataFrame(dataset["validation"]),
    ],
    axis=0,
).reset_index(drop=True)
df.head()
# Out:
#                          id                     title  \
# 0  5733be284776f41900661182  University_of_Notre_Dame
# 1  5733be284776f4190066117f  University_of_Notre_Dame
# 2  5733be284776f41900661180  University_of_Notre_Dame
# 3  5733be284776f41900661181  University_of_Notre_Dame
# 4  5733be284776f4190066117e  University_of_Notre_Dame
#
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
# 2  Architecturally, the school has a Catholic cha...
# 3  Architecturally, the school has a Catholic cha...
# 4  Architecturally, the school has a Catholic cha...
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                              answers
# 0  {'text': ['Saint Bernadette Soubirous'], 'answ...
# 1  {'text': ['a copper statue of Christ'], 'answe...
# 2  {'text': ['the Main Building'], 'answer_start'...
# 3  {'text': ['a Marian place of prayer and reflec...
# 4  {'text': ['a golden statue of the Virgin Mary'...

# %%
# Get rid of id and title
df = df.loc[:, ['context', 'question', 'answers']].copy()
df.head()
# Out:
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
# 2  Architecturally, the school has a Catholic cha...
# 3  Architecturally, the school has a Catholic cha...
# 4  Architecturally, the school has a Catholic cha...
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                              answers
# 0  {'text': ['Saint Bernadette Soubirous'], 'answ...
# 1  {'text': ['a copper statue of Christ'], 'answe...
# 2  {'text': ['the Main Building'], 'answer_start'...
# 3  {'text': ['a Marian place of prayer and reflec...
# 4  {'text': ['a golden statue of the Virgin Mary'...

# %%
# although it is called answers, there is always one element only
df['answers'] = df.answers.apply(lambda x: x['text'][0])
df.head()
# Out:
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
# 2  Architecturally, the school has a Catholic cha...
# 3  Architecturally, the school has a Catholic cha...
# 4  Architecturally, the school has a Catholic cha...
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                    answers
# 0               Saint Bernadette Soubirous
# 1                a copper statue of Christ
# 2                        the Main Building
# 3  a Marian place of prayer and reflection
# 4       a golden statue of the Virgin Mary

# %%
df.rename(
    columns={'question': 'questions', 'answer': 'answers'},
    inplace=True
)
df.head()
# Out:
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
# 2  Architecturally, the school has a Catholic cha...
# 3  Architecturally, the school has a Catholic cha...
# 4  Architecturally, the school has a Catholic cha...
#
#                                            questions  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                    answers
# 0               Saint Bernadette Soubirous
# 1                a copper statue of Christ
# 2                        the Main Building
# 3  a Marian place of prayer and reflection
# 4       a golden statue of the Virgin Mary

# %%
# Think this does nothing
df = df.loc[:, ['context', 'questions', 'answers']].copy()
df.head()
# Out:
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
# 2  Architecturally, the school has a Catholic cha...
# 3  Architecturally, the school has a Catholic cha...
# 4  Architecturally, the school has a Catholic cha...
#
#                                            questions  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                    answers
# 0               Saint Bernadette Soubirous
# 1                a copper statue of Christ
# 2                        the Main Building
# 3  a Marian place of prayer and reflection
# 4       a golden statue of the Virgin Mary

# %%
# Don't run this twice
df = df.groupby("context").agg({"questions": list, "answers": list}).reset_index()
df.head()
# Out:
#                                              context  \
# 0  \n Australia: The event was held in Canberra, ...
# 1  \n China: In China, the torch was first welcom...
# 2  \n France: The torch relay leg in Paris, held ...
# 3  \n Great Britain: The torch relay leg held in ...
# 4  \n India: Due to concerns about pro-Tibet prot...
#
#                                            questions  \
# 0  [When did the torch arrive in Canberra?, Who r...
# 1  [Action was taken to boycott which company?, W...
# 2  [When did the torch relay in Paris occur?, Whe...
# 3  [Which city hosted the 2012 Summer Olympics?, ...
# 4  [When did the torch visit New Delhi?, How many...
#
#                                              answers
# 0  [April 24, Agnes Shea, a message stick, Austra...
# 1  [Carrefour, the LVMH Group, the French flag, K...
# 2  [April 7, the Eiffel Tower, by bus, Teddy Rine...
# 3  [London, April 6, £750,000, London, Wembley St...
# 4  [April 17, 70, Baichung Bhutia, five, New Delh...
